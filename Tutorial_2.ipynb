# %% [markdown]
# <a href="https://colab.research.google.com/github/Salomey2000/TUTORIALS/blob/main/Tutorial_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from mpl_toolkits import mplot3d
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import cm
from matplotlib.ticker import LinearLocator

# %%
fig = plt.figure()
ax = plt.axes(projection='3d')

# %%
# Write a function f(x,y), where x is x1, and y is x2
def f(x,y):
  output=((x**2)+y-11)**2 + (x+(y**2)-7)**2
  return output

# %%
x = np.linspace(-10, 10, 100)
y = np.linspace(-10, 10, 100)

X, Y = np.meshgrid(x, y)
Z = f(X, Y)

# %%
# Write code below to plot the functions, you can refer to these links:
# https://matplotlib.org/stable/gallery/mplot3d/surface3d.html
# https://matplotlib.org/stable/api/_as_gen/mpl_toolkits.mplot3d.axes3d.Axes3D.plot_surface.html
# https://www.tutorialspoint.com/matplotlib/matplotlib_3d_contour_plot.htm

# %%
fig = plt.figure()
ax = plt.axes(projection='3d')

# Plot the surface.
surf = ax.plot_surface(X, Y, Z, cmap=cm.coolwarm,
                       linewidth=0,antialiased=False)
plt.show()

# %%
fig = plt.figure()
#ax = plt.axes(projection='3d')
plt.contour(X, Y, Z, 50, cmap='coolwarm')

ax.set_title('3D contour')
plt.show()

# %%
fig = plt.figure()
ax = plt.axes(projection='3d')
ax.contour3D(X, Y, Z, 50, cmap='coolwarm')
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z')
ax.set_title('3D contour')
plt.show()

# %%
# Import the necessary modules
import torch
from torch.autograd import grad

# Define the function f
def f(x, y):
    out = ((x**2)+y-11)**2 + (x+(y**2)-7)**2
    return out
# Create a tensor x and set
# requires_grad=True to track the gradient
x = torch.tensor([1.0], requires_grad=True)
y = torch.tensor([-1.0], requires_grad=True)

z = f(x,y).sum()
# Compute the gradient of f with respect to x
grad_f = grad(z, inputs=(x,y))  # read in the website below how to calculate the gradient:

# https://www.geeksforgeeks.org/how-to-differentiate-a-gradient-in-pytorch/

#print(grad_f)
# Find the gradient value
print('df(x,y)/dx = ',grad_f[0])
print('\ndf(x,y)/dy = ',grad_f[1])
# Out:
# df(x,y)/dx =  tensor([-54.])
#
# df(x,y)/dy =  tensor([-2.])

# %%
import jax.numpy as npj
from jax import grad as gradj

def fj(a, b):
    out = npj.sum(((a**2 + b - 11)**2) + ((a + b**2 - 7)**2))
    return out
drev =gradj(fj,argnums=(0, 1))

# %%
a = npj.asarray([1.0])
b = npj.asarray([-1.0])
print(drev(a,b))
# Out:
# (Array([-54.], dtype=float32), Array([-2.], dtype=float32))

# %%
# Python program to compute Hessian in PyTorch
# importing libraries
import torch
from torch.autograd.functional import hessian

# defining a function
def func(k,m):
    return (k**3 + m**3 - 3*k + 5*m).sum()

# defining the input tensor
k = torch.tensor([1.])
m = torch.tensor([0.])
input = (k,m)
# computing the hessian
output = hessian(func, input)

# printing the above computed tensor
print("Hessian:\n", output)
# Out:
# Hessian:
#  ((tensor([[6.]]), tensor([[0.]])), (tensor([[0.]]), tensor([[0.]])))
